# %%
# Import packages required for the operation

import pandas as pd

# %% [markdown]
# # Change csv encoding

# %%
# Load csvs into dataframes using utf-16 encoding and export them back to csvs using utf-8 encoding.

csvs = ['Profiles', 'Populations', 'Ticketing - 23_24', 'Ticketing - 24_25']

path = r'C:\Users\shree\Documents\Professional\Job Search 25-26\Interview Prep\PSG\Case Study - PSG\Case Study - PSG'

for file in csvs:
    df = pd.read_csv('{}\{}.csv'.format(path, file), sep = '\t', encoding = 'utf-16')
    df[:50].to_csv('{}\Work\Data\{}_utf8_for_gemini.csv'.format(path, file), index = False)
